# %% [markdown]
#                                                                         ICP -6

# %% [markdown]
# Question - 1

# %%
# Imports
import numpy as np
import pandas as pd
from keras.models import Sequential
from keras.layers import Dense
from sklearn.datasets import load_breast_cancer
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler

# Load the Breast Cancer dataset
data = load_breast_cancer()
X = data.data
y = data.target

# Normalize the data
scaler = StandardScaler()
X_scaled = scaler.fit_transform(X)

# Split the dataset into training and testing sets
X_train, X_test, Y_train, Y_test = train_test_split(X_scaled, y, test_size=0.25, random_state=87)

# Neural network model with additional dense layers
model = Sequential()
model.add(Dense(20, input_dim=X_train.shape[1], activation='relu'))  # Adjusted input_dim for Breast Cancer dataset
model.add(Dense(64, activation='relu'))  # Additional dense layer
model.add(Dense(64, activation='relu'))  # Additional dense layer
model.add(Dense(1, activation='sigmoid'))  # Output layer for binary classification

# Compile the model
model.compile(loss='binary_crossentropy', optimizer='adam', metrics=['accuracy'])

# Train the model
model.fit(X_train, Y_train, epochs=100, batch_size=10, verbose=1)

# Model summary
print(model.summary())

# Evaluate the model on the test data
loss, accuracy = model.evaluate(X_test, Y_test, verbose=0)
print(f'Test Accuracy: {accuracy*100:.2f}%')
# Out:
# Epoch 1/100
# 43/43 [==============================] - 3s 4ms/step - loss: 0.4320 - accuracy: 0.8568
# Epoch 2/100
# 43/43 [==============================] - 0s 3ms/step - loss: 0.1112 - accuracy: 0.9718
# Epoch 3/100
# 43/43 [==============================] - 0s 3ms/step - loss: 0.0604 - accuracy: 0.9765
# Epoch 4/100
# 43/43 [==============================] - 0s 4ms/step - loss: 0.0456 - accuracy: 0.9836
# Epoch 5/100
# 43/43 [==============================] - 0s 3ms/step - loss: 0.0363 - accuracy: 0.9883
# Epoch 6/100
# 43/43 [==============================] - 0s 3ms/step - loss: 0.0319 - accuracy: 0.9883
# Epoch 7/100
# 43/43 [==============================] - 0s 3ms/step - loss: 0.0246 - accuracy: 0.9930
# Epoch 8/100
# 43/43 [==============================] - 0s 4ms/step - loss: 0.0198 - accuracy: 0.9977
# Epoch 9/100
# 43/43 [==============================] - 0s 3ms/step - loss: 0.0144 - accuracy: 0.9977
# Epoch 10/100
# 43/43 [==============================] - 0s 5ms/step - loss: 0.0131 - accuracy: 0.9953
# Epoch 11/100
# 43/43 [==============================] - 0s 6ms/step - loss: 0.0104 - accuracy: 1.0000
# Epoch 12/100
# 43/43 [==============================] - 1s 13ms/step - loss: 0.0073 - accuracy: 1.0000
# Epoch 13/100
# 43/43 [==============================] - 0s 10ms/step - loss: 0.0063 - accuracy: 1.0000
# Epoch 14/100
# 43/43 [==============================] - 0s 11ms/step - loss: 0.0055 - accuracy: 1.0000
# Epoch 15/100
# 43/43 [==============================] - 0s 10ms/step - loss: 0.0046 - accuracy: 1.0000
# Epoch 16/100
# 43/43 [==============================] - 0s 10ms/step - loss: 0.0036 - accuracy: 1.0000
# Epoch 17/100
# 43/43 [==============================] - 0s 8ms/step - loss: 0.0026 - accuracy: 1.0000
# Epoch 18/100
# 43/43 [==============================] - 0s 9ms/step - loss: 0.0023 - accuracy: 1.0000
# Epoch 19/100
# 43/43 [==============================] - 0s 5ms/step - loss: 0.0020 - accuracy: 1.0000
# Epoch 20/100
# 43/43 [==============================] - 0s 5ms/step - loss: 0.0016 - accuracy: 1.0000
# Epoch 21/100
# 43/43 [==============================] - 0s 4ms/step - loss: 0.0013 - accuracy: 1.0000
# Epoch 22/100
# 43/43 [==============================] - 0s 3ms/step - loss: 0.0012 - accuracy: 1.0000
# Epoch 23/100
# 43/43 [==============================] - 0s 3ms/step - loss: 0.0011 - accuracy: 1.0000
# Epoch 24/100
# 43/43 [==============================] - 0s 3ms/step - loss: 8.9709e-04 - accuracy: 1.0000
# Epoch 25/100
# 43/43 [==============================] - 0s 3ms/step - loss: 7.1823e-04 - accuracy: 1.0000
# Epoch 26/100
# 43/43 [==============================] - 0s 3ms/step - loss: 6.5085e-04 - accuracy: 1.0000
# Epoch 27/100
# 43/43 [==============================] - 0s 3ms/step - loss: 5.9428e-04 - accuracy: 1.0000
# Epoch 28/100
# 43/43 [==============================] - 0s 2ms/step - loss: 5.3569e-04 - accuracy: 1.0000
# Epoch 29/100
# 43/43 [==============================] - 0s 2ms/step - loss: 4.7168e-04 - accuracy: 1.0000
# Epoch 30/100
# 43/43 [==============================] - 0s 2ms/step - loss: 4.2803e-04 - accuracy: 1.0000
# Epoch 31/100
# 43/43 [==============================] - 0s 2ms/step - loss: 3.8568e-04 - accuracy: 1.0000
# Epoch 32/100
# 43/43 [==============================] - 0s 2ms/step - loss: 3.4789e-04 - accuracy: 1.0000
# Epoch 33/100
# 43/43 [==============================] - 0s 2ms/step - loss: 3.1828e-04 - accuracy: 1.0000
# Epoch 34/100
# 43/43 [==============================] - 0s 2ms/step - loss: 2.9682e-04 - accuracy: 1.0000
# Epoch 35/100
# 43/43 [==============================] - 0s 2ms/step - loss: 2.6707e-04 - accuracy: 1.0000
# Epoch 36/100
# 43/43 [==============================] - 0s 2ms/step - loss: 2.4384e-04 - accuracy: 1.0000
# Epoch 37/100
# 43/43 [==============================] - 0s 2ms/step - loss: 2.2042e-04 - accuracy: 1.0000
# Epoch 38/100
# 43/43 [==============================] - 0s 2ms/step - loss: 2.1518e-04 - accuracy: 1.0000
# Epoch 39/100
# 43/43 [==============================] - 0s 2ms/step - loss: 1.9233e-04 - accuracy: 1.0000
# Epoch 40/100
# 43/43 [==============================] - 0s 2ms/step - loss: 1.7536e-04 - accuracy: 1.0000
# Epoch 41/100
# 43/43 [==============================] - 0s 2ms/step - loss: 1.6419e-04 - accuracy: 1.0000
# Epoch 42/100
# 43/43 [==============================] - 0s 2ms/step - loss: 1.5184e-04 - accuracy: 1.0000
# Epoch 43/100
# 43/43 [==============================] - 0s 2ms/step - loss: 1.4460e-04 - accuracy: 1.0000
# Epoch 44/100
# 43/43 [==============================] - 0s 2ms/step - loss: 1.3634e-04 - accuracy: 1.0000
# Epoch 45/100
# 43/43 [==============================] - 0s 2ms/step - loss: 1.2504e-04 - accuracy: 1.0000
# Epoch 46/100
# 43/43 [==============================] - 0s 2ms/step - loss: 1.1830e-04 - accuracy: 1.0000
# Epoch 47/100
# 43/43 [==============================] - 0s 2ms/step - loss: 1.1150e-04 - accuracy: 1.0000
# Epoch 48/100
# 43/43 [==============================] - 0s 2ms/step - loss: 1.0322e-04 - accuracy: 1.0000
# Epoch 49/100
# 43/43 [==============================] - 0s 2ms/step - loss: 9.8849e-05 - accuracy: 1.0000
# Epoch 50/100
# 43/43 [==============================] - 0s 2ms/step - loss: 9.2065e-05 - accuracy: 1.0000
# Epoch 51/100
# 43/43 [==============================] - 0s 2ms/step - loss: 8.7825e-05 - accuracy: 1.0000
# Epoch 52/100
# 43/43 [==============================] - 0s 2ms/step - loss: 8.3489e-05 - accuracy: 1.0000
# Epoch 53/100
# 43/43 [==============================] - 0s 2ms/step - loss: 7.7821e-05 - accuracy: 1.0000
# Epoch 54/100
# 43/43 [==============================] - 0s 2ms/step - loss: 7.5579e-05 - accuracy: 1.0000
# Epoch 55/100
# 43/43 [==============================] - 0s 2ms/step - loss: 7.0201e-05 - accuracy: 1.0000
# Epoch 56/100
# 43/43 [==============================] - 0s 2ms/step - loss: 6.6399e-05 - accuracy: 1.0000
# Epoch 57/100
# 43/43 [==============================] - 0s 2ms/step - loss: 6.3708e-05 - accuracy: 1.0000
# Epoch 58/100
# 43/43 [==============================] - 0s 2ms/step - loss: 5.9862e-05 - accuracy: 1.0000
# Epoch 59/100
# 43/43 [==============================] - 0s 2ms/step - loss: 5.6756e-05 - accuracy: 1.0000
# Epoch 60/100
# 43/43 [==============================] - 0s 2ms/step - loss: 5.3999e-05 - accuracy: 1.0000
# Epoch 61/100
# 43/43 [==============================] - 0s 2ms/step - loss: 5.1164e-05 - accuracy: 1.0000
# Epoch 62/100
# 43/43 [==============================] - 0s 2ms/step - loss: 4.9197e-05 - accuracy: 1.0000
# Epoch 63/100
# 43/43 [==============================] - 0s 2ms/step - loss: 4.6513e-05 - accuracy: 1.0000
# Epoch 64/100
# 43/43 [==============================] - 0s 2ms/step - loss: 4.5126e-05 - accuracy: 1.0000
# Epoch 65/100
# 43/43 [==============================] - 0s 2ms/step - loss: 4.2338e-05 - accuracy: 1.0000
# Epoch 66/100
# 43/43 [==============================] - 0s 2ms/step - loss: 4.0234e-05 - accuracy: 1.0000
# Epoch 67/100
# 43/43 [==============================] - 0s 2ms/step - loss: 3.8482e-05 - accuracy: 1.0000
# Epoch 68/100
# 43/43 [==============================] - 0s 2ms/step - loss: 3.6825e-05 - accuracy: 1.0000
# Epoch 69/100
# 43/43 [==============================] - 0s 2ms/step - loss: 3.4563e-05 - accuracy: 1.0000
# Epoch 70/100
# 43/43 [==============================] - 0s 2ms/step - loss: 3.2840e-05 - accuracy: 1.0000
# Epoch 71/100
# 43/43 [==============================] - 0s 2ms/step - loss: 3.1603e-05 - accuracy: 1.0000
# Epoch 72/100
# 43/43 [==============================] - 0s 2ms/step - loss: 3.0605e-05 - accuracy: 1.0000
# Epoch 73/100
# 43/43 [==============================] - 0s 2ms/step - loss: 2.8725e-05 - accuracy: 1.0000
# Epoch 74/100
# 43/43 [==============================] - 0s 2ms/step - loss: 2.7678e-05 - accuracy: 1.0000
# Epoch 75/100
# 43/43 [==============================] - 0s 2ms/step - loss: 2.6561e-05 - accuracy: 1.0000
# Epoch 76/100
# 43/43 [==============================] - 0s 2ms/step - loss: 2.5253e-05 - accuracy: 1.0000
# Epoch 77/100
# 43/43 [==============================] - 0s 2ms/step - loss: 2.4193e-05 - accuracy: 1.0000
# Epoch 78/100
# 43/43 [==============================] - 0s 2ms/step - loss: 2.3625e-05 - accuracy: 1.0000
# Epoch 79/100
# 43/43 [==============================] - 0s 2ms/step - loss: 2.2326e-05 - accuracy: 1.0000
# Epoch 80/100
# 43/43 [==============================] - 0s 2ms/step - loss: 2.1307e-05 - accuracy: 1.0000
# Epoch 81/100
# 43/43 [==============================] - 0s 2ms/step - loss: 2.0636e-05 - accuracy: 1.0000
# Epoch 82/100
# 43/43 [==============================] - 0s 2ms/step - loss: 1.9493e-05 - accuracy: 1.0000
# Epoch 83/100
# 43/43 [==============================] - 0s 2ms/step - loss: 1.8836e-05 - accuracy: 1.0000
# Epoch 84/100
# 43/43 [==============================] - 0s 2ms/step - loss: 1.8078e-05 - accuracy: 1.0000
# Epoch 85/100
# 43/43 [==============================] - 0s 2ms/step - loss: 1.7442e-05 - accuracy: 1.0000
# Epoch 86/100
# 43/43 [==============================] - 0s 2ms/step - loss: 1.6820e-05 - accuracy: 1.0000
# Epoch 87/100
# 43/43 [==============================] - 0s 2ms/step - loss: 1.5852e-05 - accuracy: 1.0000
# Epoch 88/100
# 43/43 [==============================] - 0s 2ms/step - loss: 1.5624e-05 - accuracy: 1.0000
# Epoch 89/100
# 43/43 [==============================] - 0s 2ms/step - loss: 1.4847e-05 - accuracy: 1.0000
# Epoch 90/100
# 43/43 [==============================] - 0s 2ms/step - loss: 1.4237e-05 - accuracy: 1.0000
# Epoch 91/100
# 43/43 [==============================] - 0s 2ms/step - loss: 1.3662e-05 - accuracy: 1.0000
# Epoch 92/100
# 43/43 [==============================] - 0s 2ms/step - loss: 1.3114e-05 - accuracy: 1.0000
# Epoch 93/100
# 43/43 [==============================] - 0s 2ms/step - loss: 1.2766e-05 - accuracy: 1.0000
# Epoch 94/100
# 43/43 [==============================] - 0s 2ms/step - loss: 1.2172e-05 - accuracy: 1.0000
# Epoch 95/100
# 43/43 [==============================] - 0s 2ms/step - loss: 1.1712e-05 - accuracy: 1.0000
# Epoch 96/100
# 43/43 [==============================] - 0s 2ms/step - loss: 1.1459e-05 - accuracy: 1.0000
# Epoch 97/100
# 43/43 [==============================] - 0s 2ms/step - loss: 1.0886e-05 - accuracy: 1.0000
# Epoch 98/100
# 43/43 [==============================] - 0s 2ms/step - loss: 1.0455e-05 - accuracy: 1.0000
# Epoch 99/100
# 43/43 [==============================] - 0s 2ms/step - loss: 1.0127e-05 - accuracy: 1.0000
# Epoch 100/100
# 43/43 [==============================] - 0s 2ms/step - loss: 9.8881e-06 - accuracy: 1.0000
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense (Dense)               (None, 20)                620
#
#  dense_1 (Dense)             (None, 64)                1344
#
#  dense_2 (Dense)             (None, 64)                4160
#
#  dense_3 (Dense)             (None, 1)                 65
#
# =================================================================
# Total params: 6189 (24.18 KB)
# Trainable params: 6189 (24.18 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________
# None
# Test Accuracy: 95.80%

# %% [markdown]
# Question - 2

# %%
from keras.datasets import mnist
import numpy as np
from keras.models import Sequential
from keras.layers import Dense
from keras.utils import to_categorical
import matplotlib.pyplot as plt

# Load the MNIST dataset
(train_images, train_labels), (test_images, test_labels) = mnist.load_data()

# Preprocess the data
dimData = np.prod(train_images.shape[1:])
train_data = train_images.reshape(train_images.shape[0], dimData).astype('float32') / 255
test_data = test_images.reshape(test_images.shape[0], dimData).astype('float32') / 255
train_labels_one_hot = to_categorical(train_labels)
test_labels_one_hot = to_categorical(test_labels)

# Creating the network
model = Sequential([
    Dense(512, activation='relu', input_shape=(dimData,)),
    Dense(512, activation='relu'),
    Dense(10, activation='softmax')
])

model.compile(optimizer='rmsprop', loss='categorical_crossentropy', metrics=['accuracy'])

# Train the model
history = model.fit(train_data, train_labels_one_hot, batch_size=256, epochs=10, verbose=1,
                    validation_data=(test_data, test_labels_one_hot))

# Plotting the accuracy and loss
plt.figure(figsize=(12, 5))
plt.subplot(1, 2, 1)
plt.plot(history.history['accuracy'], label='Training Accuracy')
plt.plot(history.history['val_accuracy'], label='Validation Accuracy')
plt.title('Accuracy')
plt.legend()

plt.subplot(1, 2, 2)
plt.plot(history.history['loss'], label='Training Loss')
plt.plot(history.history['val_loss'], label='Validation Loss')
plt.title('Loss')
plt.legend()
plt.show()

# Predicting a single image
def predict_single_image(image_data):
    image_data = image_data.reshape(1, dimData).astype('float32') / 255
    prediction = model.predict(image_data)
    predicted_class = np.argmax(prediction)
    return predicted_class

# Choose an image from the test set
image_index = 0  # Change this to see different predictions
predicted_class = predict_single_image(test_images[image_index])
print(f'Predicted class for image at index {image_index}: {predicted_class}')
plt.imshow(test_images[image_index], cmap='gray')
plt.title(f'Image at index {image_index} - Predicted as: {predicted_class}')
plt.show()

# Modify the model to use different activation functions and fewer layers for comparison
# You can adjust the following model architecture as needed
model_tanh = Sequential([
    Dense(512, activation='tanh', input_shape=(dimData,)),
    Dense(10, activation='softmax')
])

model_tanh.compile(optimizer='rmsprop', loss='categorical_crossentropy', metrics=['accuracy'])
model_tanh.fit(train_data, train_labels_one_hot, batch_size=256, epochs=10, verbose=1,
               validation_data=(test_data, test_labels_one_hot))

# To compare performance without scaling, you would need to adjust the data preprocessing
# and re-train the model. This is not included here for brevity but can be done by removing
# the division by 255 in the data preprocessing steps.
# Out:
# Epoch 1/10
# 235/235 [==============================] - 6s 22ms/step - loss: 0.2937 - accuracy: 0.9105 - val_loss: 0.1527 - val_accuracy: 0.9542
# Epoch 2/10
# 235/235 [==============================] - 6s 25ms/step - loss: 0.0994 - accuracy: 0.9693 - val_loss: 0.1007 - val_accuracy: 0.9689
# Epoch 3/10
# 235/235 [==============================] - 5s 21ms/step - loss: 0.0626 - accuracy: 0.9805 - val_loss: 0.0646 - val_accuracy: 0.9796
# Epoch 4/10
# 235/235 [==============================] - 6s 25ms/step - loss: 0.0445 - accuracy: 0.9857 - val_loss: 0.0823 - val_accuracy: 0.9736
# Epoch 5/10
# 235/235 [==============================] - 5s 21ms/step - loss: 0.0310 - accuracy: 0.9901 - val_loss: 0.0663 - val_accuracy: 0.9793
# Epoch 6/10
# 235/235 [==============================] - 5s 21ms/step - loss: 0.0219 - accuracy: 0.9932 - val_loss: 0.0734 - val_accuracy: 0.9807
# Epoch 7/10
# 235/235 [==============================] - 6s 25ms/step - loss: 0.0178 - accuracy: 0.9942 - val_loss: 0.0684 - val_accuracy: 0.9822
# Epoch 8/10
# 235/235 [==============================] - 5s 21ms/step - loss: 0.0130 - accuracy: 0.9960 - val_loss: 0.0868 - val_accuracy: 0.9769
# Epoch 9/10
# 235/235 [==============================] - 6s 25ms/step - loss: 0.0098 - accuracy: 0.9970 - val_loss: 0.0652 - val_accuracy: 0.9845
# Epoch 10/10
# 235/235 [==============================] - 5s 21ms/step - loss: 0.0080 - accuracy: 0.9977 - val_loss: 0.0643 - val_accuracy: 0.9855
# 1/1 [==============================] - 0s 55ms/step
# Predicted class for image at index 0: 7
# Epoch 1/10
# 235/235 [==============================] - 4s 18ms/step - loss: 0.3922 - accuracy: 0.8846 - val_loss: 0.2624 - val_accuracy: 0.9238
# Epoch 2/10
# 235/235 [==============================] - 3s 13ms/step - loss: 0.2357 - accuracy: 0.9316 - val_loss: 0.2399 - val_accuracy: 0.9265
# Epoch 3/10
# 235/235 [==============================] - 3s 13ms/step - loss: 0.1718 - accuracy: 0.9507 - val_loss: 0.1671 - val_accuracy: 0.9502
# Epoch 4/10
# 235/235 [==============================] - 3s 13ms/step - loss: 0.1300 - accuracy: 0.9623 - val_loss: 0.1348 - val_accuracy: 0.9605
# Epoch 5/10
# 235/235 [==============================] - 4s 17ms/step - loss: 0.1032 - accuracy: 0.9698 - val_loss: 0.1191 - val_accuracy: 0.9635
# Epoch 6/10
# 235/235 [==============================] - 3s 13ms/step - loss: 0.0835 - accuracy: 0.9755 - val_loss: 0.0923 - val_accuracy: 0.9715
# Epoch 7/10
# 235/235 [==============================] - 3s 13ms/step - loss: 0.0691 - accuracy: 0.9801 - val_loss: 0.0785 - val_accuracy: 0.9761
# Epoch 8/10
# 235/235 [==============================] - 3s 13ms/step - loss: 0.0581 - accuracy: 0.9830 - val_loss: 0.0783 - val_accuracy: 0.9750
# Epoch 9/10
# 235/235 [==============================] - 4s 17ms/step - loss: 0.0490 - accuracy: 0.9863 - val_loss: 0.0834 - val_accuracy: 0.9738
# Epoch 10/10
# 235/235 [==============================] - 3s 13ms/step - loss: 0.0415 - accuracy: 0.9883 - val_loss: 0.0815 - val_accuracy: 0.9760
